# %%
import pandas as pd
import json
import a
import re
import ast


import warnings
warnings.filterwarnings("ignore")

# %%
archivo = 'output_steam_games.json'
# Ruta al dataset australian_user_reviews


# Se lee de cada línea del dataset
fs = []
with open(archivo, encoding='utf-8') as f:
    for line in f.readlines():
        data = json.loads(line)
        fs.append(data)

# Se convierte en dataframe
df_1 = pd.DataFrame(fs)
df_1
# Out:
#               publisher                                 genres  \
# 0                   NaN                                    NaN
# 1                   NaN                                    NaN
# 2                   NaN                                    NaN
# 3                   NaN                                    NaN
# 4                   NaN                                    NaN
# ...                 ...                                    ...
# 120440  Ghost_RUS Games  [Casual, Indie, Simulation, Strategy]
# 120441           Sacada              [Casual, Indie, Strategy]
# 120442     Laush Studio            [Indie, Racing, Simulation]
# 120443         SIXNAILS                        [Casual, Indie]
# 120444              NaN                                    NaN
#
#                         app_name                     title  \
# 0                            NaN                       NaN
# 1                            NaN                       NaN
# ...

# %%
# Eliminamos las filas con todos los registros nulos
df_2 = df_1.dropna(how='all').reset_index(drop=True)
df_2.shape
# Out:
# (32135, 13)

# %%
# Lo guardo en CSV para analizarlo visualmente
df_2.to_csv('steam_games_output.csv', index=False)
df_2
# Out:
#               publisher                                             genres  \
# 0             Kotoshiro      [Action, Casual, Indie, Simulation, Strategy]
# 1      Making Fun, Inc.               [Free to Play, Indie, RPG, Strategy]
# 2          Poolians.com  [Casual, Free to Play, Indie, Simulation, Sports]
# 3                  彼岸领域                        [Action, Adventure, Casual]
# 4                   NaN                                                NaN
# ...                 ...                                                ...
# 32130   Ghost_RUS Games              [Casual, Indie, Simulation, Strategy]
# 32131            Sacada                          [Casual, Indie, Strategy]
# 32132      Laush Studio                        [Indie, Racing, Simulation]
# 32133          SIXNAILS                                    [Casual, Indie]
# 32134               NaN                                                NaN
#
#                        app_name                     title  \
# ...

# %% [markdown]
# Analizando el CSV veo que hay juegos donde no existen datos del developer. No obstante los mantengo pues probablemente pueda necesitarlos para las recomendaciones.

# %%
# Aplico una función a la columna release_date para quedarme con el año de las fechas válidas (YYYY-MM-DD). 
# Crea columna nueva con el año
df_2['release_year'] = df_2['release_date'].apply(a.obtener_anio_release)
# elimina la columna 'release_date'
df_3= df_2.drop('release_date', axis=1)
df_3.head(1)
# Out:
#    publisher                                         genres  \
# 0  Kotoshiro  [Action, Casual, Indie, Simulation, Strategy]
#
#               app_name                title  \
# 0  Lost Summoner Kitty  Lost Summoner Kitty
#
#                                                  url  \
# 0  http://store.steampowered.com/app/761140/Lost_...
#
#                                             tags  \
# 0  [Strategy, Action, Indie, Casual, Simulation]
#
#                                          reviews_url            specs price  \
# 0  http://steamcommunity.com/app/761140/reviews/?...  [Single-player]  4.99
#
#   early_access      id  developer release_year
# 0        False  761140  Kotoshiro         2018

# %%
# Elimino las filas que no me van a servir.
df_4 = df_3.drop(['publisher', 'app_name', 'url', 'tags',  'reviews_url', 'specs', 'price', 'early_access'], axis = 1)

# %%
# Ahora elimino duplicados en id
df_4.drop_duplicates(subset='id', inplace=True, keep='first')
df_4.reset_index(drop=True, inplace=True) 
df_4
# Out:
#                                                   genres  \
# 0          [Action, Casual, Indie, Simulation, Strategy]
# 1                   [Free to Play, Indie, RPG, Strategy]
# 2      [Casual, Free to Play, Indie, Simulation, Sports]
# 3                            [Action, Adventure, Casual]
# 4                                                    NaN
# ...                                                  ...
# 32128              [Casual, Indie, Simulation, Strategy]
# 32129                          [Casual, Indie, Strategy]
# 32130                        [Indie, Racing, Simulation]
# 32131                                    [Casual, Indie]
# 32132                                                NaN
#
#                           title      id                 developer  \
# 0           Lost Summoner Kitty  761140                 Kotoshiro
# 1                     Ironbound  643980          Secret Level SRL
# 2       Real Pool 3D - Poolians  670290              Poolians.com
# ...

# %% [markdown]
# Los nombres de los juegos realizan una mezcla intencionada de mayúsculas y minúsculas, o palabras sin sentido aparente. Buscándolos en **https://store.steampowered.com/** compruebo que efectivamente están bien escritos en el dataframe, con lo cual no realizaré ningún tipo de tratamiento a dichas cadenas de texto.

# %%
df_4
# Out:
#                                                   genres  \
# 0          [Action, Casual, Indie, Simulation, Strategy]
# 1                   [Free to Play, Indie, RPG, Strategy]
# 2      [Casual, Free to Play, Indie, Simulation, Sports]
# 3                            [Action, Adventure, Casual]
# 4                                                    NaN
# ...                                                  ...
# 32128              [Casual, Indie, Simulation, Strategy]
# 32129                          [Casual, Indie, Strategy]
# 32130                        [Indie, Racing, Simulation]
# 32131                                    [Casual, Indie]
# 32132                                                NaN
#
#                           title      id                 developer  \
# 0           Lost Summoner Kitty  761140                 Kotoshiro
# 1                     Ironbound  643980          Secret Level SRL
# 2       Real Pool 3D - Poolians  670290              Poolians.com
# ...

# %%
nulos = df_4["developer"].isna().sum()
print('Nulos developer ', nulos)
nulos = df_4["title"].isna().sum()
print('Nulos title ', nulos)
# Out:
# Nulos developer  3299
# Nulos title  2050

# %%
# Eliminamos los nulos en base a title. Existen títulos donde no hay información del desarrollador pero aún así pueden ser de utilidad en las recomendaciones, por ello los mantenemos.
df_5 = df_4.dropna(subset=['title'])

# %%
df_5
# Out:
#                                                   genres  \
# 0          [Action, Casual, Indie, Simulation, Strategy]
# 1                   [Free to Play, Indie, RPG, Strategy]
# 2      [Casual, Free to Play, Indie, Simulation, Sports]
# 3                            [Action, Adventure, Casual]
# 5                        [Action, Adventure, Simulation]
# ...                                                  ...
# 32127                 [Action, Adventure, Casual, Indie]
# 32128              [Casual, Indie, Simulation, Strategy]
# 32129                          [Casual, Indie, Strategy]
# 32130                        [Indie, Racing, Simulation]
# 32131                                    [Casual, Indie]
#
#                           title      id                 developer release_year
# 0           Lost Summoner Kitty  761140                 Kotoshiro         2018
# 1                     Ironbound  643980          Secret Level SRL         2018
# ...

# %% [markdown]
# Elimino las filas con el id corrompido. Son aquellas con el string '&amp' en la columna title ó genres.

# %%
df_5 = df_5.explode('genres')
df_5 = df_5.dropna(subset=['genres'])
df_5.head()
# Out:
#        genres                title      id  developer release_year
# 0      Action  Lost Summoner Kitty  761140  Kotoshiro         2018
# 0      Casual  Lost Summoner Kitty  761140  Kotoshiro         2018
# 0       Indie  Lost Summoner Kitty  761140  Kotoshiro         2018
# 0  Simulation  Lost Summoner Kitty  761140  Kotoshiro         2018
# 0    Strategy  Lost Summoner Kitty  761140  Kotoshiro         2018

# %%
# Eliminamos filas que contengan '&amp' y 'Dato no disponible'
condicion = df_5['genres'].str.contains('&amp', regex=True) | df_5['title'].str.contains('&amp', regex=True) | df_5['developer'].str.contains('&amp', regex=True) | df_5['release_year'].str.contains('Dato no disponible', regex=True)
df_6 = df_5[~condicion]

# %%
df_6.reset_index(drop=True, inplace=True)
df_6
# Out:
#            genres                title      id                 developer  \
# 0          Action  Lost Summoner Kitty  761140                 Kotoshiro
# 1          Casual  Lost Summoner Kitty  761140                 Kotoshiro
# 2           Indie  Lost Summoner Kitty  761140                 Kotoshiro
# 3      Simulation  Lost Summoner Kitty  761140                 Kotoshiro
# 4        Strategy  Lost Summoner Kitty  761140                 Kotoshiro
# ...           ...                  ...     ...                       ...
# 68605       Indie        Russian Roads  610660  Laush Dmitriy Sergeevich
# 68606      Racing        Russian Roads  610660  Laush Dmitriy Sergeevich
# 68607  Simulation        Russian Roads  610660  Laush Dmitriy Sergeevich
# 68608      Casual  EXIT 2 - Directions  658870             xropi,stev3ns
# 68609       Indie  EXIT 2 - Directions  658870             xropi,stev3ns
#
#       release_year
# 0             2018
# 1             2018
# 2             2018
# ...

# %%
# Elimino todas la filas que tienen valores nulos en 'id' o 'developer'
df_7 = df_6.dropna(subset=['id', 'developer'])
# Reconstruyo índices
df_7.reset_index(drop=True, inplace=True)
df_7
# Out:
#            genres                title      id                 developer  \
# 0          Action  Lost Summoner Kitty  761140                 Kotoshiro
# 1          Casual  Lost Summoner Kitty  761140                 Kotoshiro
# 2           Indie  Lost Summoner Kitty  761140                 Kotoshiro
# 3      Simulation  Lost Summoner Kitty  761140                 Kotoshiro
# 4        Strategy  Lost Summoner Kitty  761140                 Kotoshiro
# ...           ...                  ...     ...                       ...
# 68257       Indie        Russian Roads  610660  Laush Dmitriy Sergeevich
# 68258      Racing        Russian Roads  610660  Laush Dmitriy Sergeevich
# 68259  Simulation        Russian Roads  610660  Laush Dmitriy Sergeevich
# 68260      Casual  EXIT 2 - Directions  658870             xropi,stev3ns
# 68261       Indie  EXIT 2 - Directions  658870             xropi,stev3ns
#
#       release_year
# 0             2018
# 1             2018
# 2             2018
# ...

# %%
# Convierto el tipo de datos de las columnas id y release_year a entero
df_7['release_year'] = df_7['release_year'].astype(int)
df_7['id'] = df_7['id'].astype(int)

# %%
# Guardo el dataset con formato CSV
archivo = 'steam_games_output_limpio.csv'
df_6.to_csv(archivo, index=False)
# Lo guardo en parquet para la API
df_6.to_parquet('steam_games_output_limpio.parquet', compression='gzip')
